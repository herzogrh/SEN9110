# %% [markdown]
# # Assignment 1
# ## Ferry Model | Group 14
# ### Imports

# %%
import salabim as sim
import numpy as np
import pandas as pd
import time, sys, random

# %% [markdown]
# ## Time Data

# %%
CAR_NUMBERS = pd.read_csv("TimeTable.csv", sep=";")

# %% [markdown]
# ## Variables

# %%
SAILING_TIME = sim.Triangular(10,18,13)
NUMBER_OF_CARS = sim.Triangular(70,80,75)
PAYMENT_TIME = sim.Triangular(1,4,2)
LOADING_TIME = sim.Exponential(1/6) # 10 seconds per car
UNLOADING_TIME = sim.Exponential(5/60) # 5 seconds per time
WAITING_TIME_PREPAID = sim.Exponential(0.5) # minutes
PERCENTAGE_PREPAID = 0.2 

SIM_TIME = 60*24 # Time in minutes
REPLICATIONS = 10 # Number of experiment replications

# %% [markdown]
# ## Components
# ### Class Car

# %%
class Car(sim.Component):
    def setup(self, cartype, paid, location):
        self.cartype = cartype # either tourist or employee
        self.paid = paid # true for prepaid, false for not prepaid
        self.location = location # either mainland or island

    def process(self):  
        # Go to the assigned booth and line depending on the cartype, prepaid and locations
        ## Employee type
        if self.cartype == "employee":
            if self.location == "mainland":
                self.enter(mainland_line1)
            else: 
                self.enter(island_line1)
        ## Tourists
        else: 
            # In case the tourist has prepaid 
            if self.paid:
                if self.location == "mainland":
                    self.enter(mainland_line2_1)
                    if prePaidBooth_mainland.ispassive():
                        prePaidBooth_mainland.activate()

                    self.enter(mainland_line2)
                    
                else: 
                    self.enter(island_line2_1)
                    
                    if prePaidBooth_island.ispassive():
                        prePaidBooth_island.activate()

                    self.enter(island_line2)

            # In case the tourist still has to pay
            else: 
                if self.location == "mainland":
                    self.enter(mainland_line3_1)
                    if payingBooth_mainland.ispassive():
                        payingBooth_mainland.activate()

                    self.enter(mainland_line3)
                    
                else: 
                    self.enter(island_line3_1)
                    
                    if payingBooth_island.ispassive():
                        payingBooth_island.activate()

                    self.enter(island_line3)
            
            # Passivate the component
        yield self.passivate()

# %% [markdown]
# ### Car Generator

# %%
class CarGenerator(sim.Component):
    def setup(self, location, cartype):
        self.cartype = cartype # either tourist or employee
        self.location = location # either mainland or island

    def process(self):
        while True:
            #Get current time
            CurrentCarNumbers = CAR_NUMBERS[CAR_NUMBERS["time"]<= (env.now()/60)].tail(1)

            # Generate a car
            Car(cartype = self.cartype, paid = (random.random() < 0.2), location= self.location)

            # Wait for the correct amount of time until creating the next car
            ## Get the number of cars
            number_cars = int(CurrentCarNumbers[str(self.cartype) + "_" + str(self.location)])

            ## Calculate the time span the cars arrive in 
            time_span = int(CAR_NUMBERS["time"].iloc[CurrentCarNumbers.index + 1]) - int(CAR_NUMBERS["time"].iloc[CurrentCarNumbers.index])

            ## Check if number of cars is greater than zero, then wait the correct amount of time, otherwise wait for the time interval
            if number_cars > 0:
                # Interarrival times are based on an exponential equation
                yield self.hold(sim.Exponential(60*time_span / number_cars))
            else:
                yield self.hold(60*time_span)

# %% [markdown]
# ### Ferry

# %%
class Ferry(sim.Component):
    def setup(self, capacity, carsonferry, ferryrides, location):
        self.capacity = capacity # indicates how much space there is on the ferry
        self.carsonferry = carsonferry # indicates how many cars there are currently on the ferry 
        self.ferryrides = ferryrides # counts the amount of ferryrides done
        self.location = location # the location of the ferry (either mainland or island)


    def process(self):
        while True:
            # Wait until both the departure time is reached and the ferry is loaded
            yield self.wait(departuretime, ferryloaded, all=True)

            # Add one more ride to the ferry ride attribute
            self.ferryrides += 1

            # Cruise
            yield self.hold(SAILING_TIME.sample())

            # Change the location of the ferry
            if self.location == "mainland":
                self.location = "island"
            else:
                self.location = "mainland"

            # Unload
            for i in range(self.carsonferry):
                yield self.hold(sim.Exponential())



    def load(self):  
        yield self.hold(5)



class FerryOperator(sim.Component):
    def process(self):

        
        while True:
            # Load the ferry
            CanadianFerry.activate(process='load')

# %%
class Server(sim.Component):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.activeTime = 0
        self.activeTimeManual = 0
        self.startProcessTime = -1

    def startUtilTime(self):
        self.startProcessTime = env.now()

    def endUtilTime(self):
        if self.startProcessTime >= 0:
            endNow = env.now()
            self.activeTime += endNow - self.startProcessTime
            self.startProcessTime = -1

    def getUtilization(self):
        return self.activeTime / (env.now() - self._creation_time)

    def getUtilizationManual(self):
        return self.activeTimeManual / (env.now() - self._creation_time)

class PrePaidBooth(Server):
    
    def setup(self, location):
        self.location = location # either mainland or island

    
    def process(self):
        while True:
            if self.location == "mainland":
                while len(mainland_line2_1) == 0:
                    yield self.passivate()

                self.startUtilTime()
                self.car = mainland_line2_1.pop()

                yield self.hold(WAITING_TIME_PREPAID.sample())

                self.car.activate()
                
            elif self.location == "island":
                while len(island_line2_1) == 0:
                    yield self.passivate()

                self.startUtilTime()
                self.car = island_line2_1.pop()

                yield self.hold(WAITING_TIME_PREPAID.sample())

                self.car.activate()

                
class PayingBooth(Server):
    
    def setup(self, location):
        self.location = location # either mainland or island

    
    def process(self):
        while True:
            if self.location == "mainland":
                while len(mainland_line3_1) == 0:
                    yield self.passivate()

                self.startUtilTime()
                self.car = mainland_line3_1.pop()

                yield self.hold(PAYMENT_TIME.sample())

                self.car.activate()
                
            elif self.location == "island":
                while len(island_line3_1) == 0:
                    yield self.passivate()

                self.startUtilTime()
                self.car = island_line3_1.pop()

                yield self.hold(PAYMENT_TIME.sample())

                self.car.activate()

# %% [markdown]
# ### Creating and running the environment

# %%
# Create the Environment
env = sim.Environment(time_unit='minutes', trace= True)
env.modelname("Canadian Ferries Simulation")

# Create a ferry at the beginning of the simulation
CanadianFerry = Ferry(capacity = NUMBER_OF_CARS.sample(), carsonferry = 0, ferryrides = 0, location = "mainland")

# States
departuretime = sim.State('departuretime', value=False)
ferryloaded = sim.State('ferryloaded', value=False)

#Queues
mainland_line1, mainland_line2, mainland_line3 = sim.Queue('mainland_line1'), sim.Queue('mainland_line2'), sim.Queue('mainland_line3')
island_line1, island_line2, island_line3 = sim.Queue('island_line1'), sim.Queue('island_line2'), sim.Queue('island_line3')
mainland_line2_1, mainland_line3_1 = sim.Queue('mainland_line2_1'), sim.Queue('mainland_line3_1')
island_line2_1, island_line3_1 = sim.Queue('island_line2_1'), sim.Queue('island_line3_1')

# Activate the Ferry operators on 6:30
FerryOperator(at=6.5*60)

# Initiate the Car Generators
CarGenerator(cartype="employee", location="island")
CarGenerator(cartype="employee", location="mainland")
CarGenerator(cartype="tourist", location="island")
CarGenerator(cartype="tourist", location="mainland")

prePaidBooth_mainland = PrePaidBooth(location="mainland")
prePaidBooth_island = PrePaidBooth(location="island")
payingBooth_mainland = PayingBooth(location="mainland")
payingBooth_island = PayingBooth(location="island")

env.run(duration=SIM_TIME)
print()
# Out:
# line#        time current component    action                               information
# ------ ---------- -------------------- -----------------------------------  ------------------------------------------------
#                                        line numbers refers to               <ipython-input-11-5a31fec69194>
#     2                                  default environment initialize
#     2                                  main create
#     2       0.000 main                 current
#     6                                  ferry.0 create
#                                        line numbers prefixed by A refer to  <ipython-input-6-bd323060af8b>
#     6                                  ferry.0 activate                     scheduled for      0.000 @   A9  process=process
#     9                                  departuretime create                 value= False
#    10                                  ferryloaded create                   value= False
#    13                                  mainland_line1 create
#    13                                  mainland_line2 create
#    13                                  mainland_line3 create
#    14                                  island_line1 create
#    14                                  island_line2 create
#    14                                  island_line3 create
#    15                                  mainland_line2_1 create
#    15                                  mainland_line3_1 create
#    16                                  island_line2_1 create
#    16                                  island_line3_1 create
#    19                                  ferryoperator.0 create
#    19                                  ferryoperator.0 activate +390.000    scheduled for    390.000   A38  process=process
#    22                                  cargenerator.0 create
#                                        line numbers prefixed by B refer to  <ipython-input-5-8c0a49d4c80d>
#    22                                  cargenerator.0 activate              scheduled for      0.000 @   B6  process=process
#    23                                  cargenerator.1 create
#    23                                  cargenerator.1 activate              scheduled for      0.000 @   B6  process=process
#    24                                  cargenerator.2 create
#    24                                  cargenerator.2 activate              scheduled for      0.000 @   B6  process=process
#    25                                  cargenerator.3 create
#    25                                  cargenerator.3 activate              scheduled for      0.000 @   B6  process=process
#                                        line numbers prefixed by C refer to  <ipython-input-10-0eecb586755e>
#    C3                                  prepaidbooth.0 create
#    C3                                  prepaidbooth.0 activate              scheduled for      0.000 @  C29  process=process
#    C3                                  prepaidbooth.1 create
#    C3                                  prepaidbooth.1 activate              scheduled for      0.000 @  C29  process=process
#    C3                                  payingbooth.0 create
#    C3                                  payingbooth.0 activate               scheduled for      0.000 @  C60  process=process
#    C3                                  payingbooth.1 create
#    C3                                  payingbooth.1 activate               scheduled for      0.000 @  C60  process=process
#    32                                  main run +1440.000                   scheduled for   1440.000 @   32+
#    A9       0.000 ferry.0              current
#   A12                                  ferry.0 wait                         scheduled for        inf @  A12+
#    B6       0.000 cargenerator.0       current
#   B12                                  car.0 create
#                                        line numbers prefixed by D refer to  <ipython-input-4-fd8df31d467a>
#   B12                                  car.0 activate                       scheduled for      0.000 @   D7  process=process
#   B26                                  cargenerator.0 hold +360.000         scheduled for    360.000 @  B26+
#    B6       0.000 cargenerator.1       current
#   B12                                  car.1 create
#   B12                                  car.1 activate                       scheduled for      0.000 @   D7  process=process
#   B26                                  cargenerator.1 hold +360.000         scheduled for    360.000 @  B26+
#    B6       0.000 cargenerator.2       current
#   B12                                  car.2 create
#   B12                                  car.2 activate                       scheduled for      0.000 @   D7  process=process
#   B26                                  cargenerator.2 hold +360.000         scheduled for    360.000 @  B26+
#    B6       0.000 cargenerator.3       current
#   B12                                  car.3 create
#   B12                                  car.3 activate                       scheduled for      0.000 @   D7  process=process
#   B26                                  cargenerator.3 hold +360.000         scheduled for    360.000 @  B26+
#   C29       0.000 prepaidbooth.0       current
#   C33                                  prepaidbooth.0 passivate
#   C29       0.000 prepaidbooth.1       current
#   C44                                  prepaidbooth.1 passivate
#   C60       0.000 payingbooth.0        current
#   C64                                  payingbooth.0 passivate
#   C60       0.000 payingbooth.1        current
#   C75                                  payingbooth.1 passivate
#    D7       0.000 car.0                current
#   D14                                  car.0                                enter island_line1
#   D52                                  car.0 passivate
#    D7       0.000 car.1                current
#   D12                                  car.1                                enter mainland_line1
#   D52                                  car.1 passivate
#    D7       0.000 car.2                current
#   D44                                  car.2                                enter island_line3_1
#   D47                                  payingbooth.1 activate               scheduled for      0.000 @  C75+
#   D49                                  car.2                                enter island_line3
#   D52                                  car.2 passivate
#    D7       0.000 car.3                current
#   D37                                  car.3                                enter mainland_line3_1
#   D39                                  payingbooth.0 activate               scheduled for      0.000 @  C64+
#   D41                                  car.3                                enter mainland_line3
#   D52                                  car.3 passivate
#   C75+      0.000 payingbooth.1        current
#   C78                                  car.2                                leave island_line3_1
#   C80                                  payingbooth.1 hold +2.473            scheduled for      2.473 @  C80+
#   C64+      0.000 payingbooth.0        current
#   C67                                  car.3                                leave mainland_line3_1
#   C69                                  payingbooth.0 hold +1.472            scheduled for      1.472 @  C69+
#   C69+      1.472 payingbooth.0        current
#   C71                                  car.3 activate                       scheduled for      1.472 @  D52+
#   C64                                  payingbooth.0 passivate
#   D52+      1.472 car.3                current
#    32                                  car.3 ended
#   C80+      2.473 payingbooth.1        current
#   C82                                  car.2 activate                       scheduled for      2.473 @  D52+
#   C75                                  payingbooth.1 passivate
#   D52+      2.473 car.2                current
#    32                                  car.2 ended
#   B26+    360.000 cargenerator.0       current
#   B12                                  car.4 create
#   B12                                  car.4 activate                       scheduled for    360.000 @   D7  process=process
#   B24                                  cargenerator.0 hold +7.585           scheduled for    367.585 @  B24+
#   B26+    360.000 cargenerator.1       current
#   B12                                  car.5 create
#   B12                                  car.5 activate                       scheduled for    360.000 @   D7  process=process
#   B24                                  cargenerator.1 hold +9.005           scheduled for    369.005 @  B24+
#   B26+    360.000 cargenerator.2       current
#   B12                                  car.6 create
#   B12                                  car.6 activate                       scheduled for    360.000 @   D7  process=process
#   B24                                  cargenerator.2 hold +267.904         scheduled for    627.904 @  B24+
#   B26+    360.000 cargenerator.3       current
#   B12                                  car.7 create
#   B12                                  car.7 activate                       scheduled for    360.000 @   D7  process=process
#   B24                                  cargenerator.3 hold +25.827          scheduled for    385.827 @  B24+
#    D7     360.000 car.4                current
#   D14                                  car.4                                enter island_line1
#   D52                                  car.4 passivate
#    D7     360.000 car.5                current
#   D12                                  car.5                                enter mainland_line1
#   D52                                  car.5 passivate
#    D7     360.000 car.6                current
#   D27                                  car.6                                enter island_line2_1
#   D30                                  prepaidbooth.1 activate              scheduled for    360.000 @  C44+
#   D32                                  car.6                                enter island_line2
#   D52                                  car.6 passivate
#    D7     360.000 car.7                current
#   D37                                  car.7                                enter mainland_line3_1
#   D39                                  payingbooth.0 activate               scheduled for    360.000 @  C64+
#   D41                                  car.7                                enter mainland_line3
#   D52                                  car.7 passivate
#   C44+    360.000 prepaidbooth.1       current
#   C47                                  car.6                                leave island_line2_1
#   C49                                  prepaidbooth.1 hold +0.394           scheduled for    360.394 @  C49+
#   C64+    360.000 payingbooth.0        current
#   C67                                  car.7                                leave mainland_line3_1
#   C69                                  payingbooth.0 hold +1.874            scheduled for    361.874 @  C69+
#   C49+    360.394 prepaidbooth.1       current
#   C51                                  car.6 activate                       scheduled for    360.394 @  D52+
#   C44                                  prepaidbooth.1 passivate
#   D52+    360.394 car.6                current
#    32                                  car.6 ended
#   C69+    361.874 payingbooth.0        current
#   C71                                  car.7 activate                       scheduled for    361.874 @  D52+
#   C64                                  payingbooth.0 passivate
#   D52+    361.874 car.7                current
#    32                                  car.7 ended
#   B24+    367.585 cargenerator.0       current
#   B12                                  car.8 create
#   B12                                  car.8 activate                       scheduled for    367.585 @   D7  process=process
#   B24                                  cargenerator.0 hold +5.008           scheduled for    372.593 @  B24+
#    D7     367.585 car.8                current
#   D14                                  car.8                                enter island_line1
#   D52                                  car.8 passivate
#   B24+    369.005 cargenerator.1       current
#   B12                                  car.9 create
#   B12                                  car.9 activate                       scheduled for    369.005 @   D7  process=process
#   B24                                  cargenerator.1 hold +7.077           scheduled for    376.082 @  B24+
#    D7     369.005 car.9                current
#   D12                                  car.9                                enter mainland_line1
#   D52                                  car.9 passivate
#   B24+    372.593 cargenerator.0       current
#   B12                                  car.10 create
#   B12                                  car.10 activate                      scheduled for    372.593 @   D7  process=process
#   B24                                  cargenerator.0 hold +4.224           scheduled for    376.817 @  B24+
#    D7     372.593 car.10               current
#   D14                                  car.10                               enter island_line1
#   D52                                  car.10 passivate
#   B24+    376.082 cargenerator.1       current
#   B12                                  car.11 create
#   B12                                  car.11 activate                      scheduled for    376.082 @   D7  process=process
#   B24                                  cargenerator.1 hold +11.788          scheduled for    387.870 @  B24+
#    D7     376.082 car.11               current
#   D12                                  car.11                               enter mainland_line1
#   D52                                  car.11 passivate
#   B24+    376.817 cargenerator.0       current
#   B12                                  car.12 create
#   B12                                  car.12 activate                      scheduled for    376.817 @   D7  process=process
#   B24                                  cargenerator.0 hold +8.594           scheduled for    385.411 @  B24+
#    D7     376.817 car.12               current
#   D14                                  car.12                               enter island_line1
#   D52                                  car.12 passivate
#   B24+    385.411 cargenerator.0       current
#   B12                                  car.13 create
#   B12                                  car.13 activate                      scheduled for    385.411 @   D7  process=process
#   B24                                  cargenerator.0 hold +5.727           scheduled for    391.138 @  B24+
#    D7     385.411 car.13               current
#   D14                                  car.13                               enter island_line1
#   D52                                  car.13 passivate
#   B24+    385.827 cargenerator.3       current
#   B12                                  car.14 create
#   B12                                  car.14 activate                      scheduled for    385.827 @   D7  process=process
#   B24                                  cargenerator.3 hold +21.298          scheduled for    407.126 @  B24+
#    D7     385.827 car.14               current
#   D37                                  car.14                               enter mainland_line3_1
#   D39                                  payingbooth.0 activate               scheduled for    385.827 @  C64+
#   D41                                  car.14                               enter mainland_line3
#   D52                                  car.14 passivate
#   C64+    385.827 payingbooth.0        current
#   C67                                  car.14                               leave mainland_line3_1
#   C69                                  payingbooth.0 hold +3.110            scheduled for    388.938 @  C69+
#   B24+    387.870 cargenerator.1       current
#   B12                                  car.15 create
#   B12                                  car.15 activate                      scheduled for    387.870 @   D7  process=process
#   B24                                  cargenerator.1 hold +2.916           scheduled for    390.786 @  B24+
#    D7     387.870 car.15               current
#   D12                                  car.15                               enter mainland_line1
#   D52                                  car.15 passivate
#   C69+    388.938 payingbooth.0        current
#   C71                                  car.14 activate                      scheduled for    388.938 @  D52+
#   C64                                  payingbooth.0 passivate
#   D52+    388.938 car.14               current
#    32                                  car.14 ended
#   A38     390.000 ferryoperator.0      current
#   A43                                  ferry.0                              wait failed
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
# ...
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
#   A43                                  ferry.0 activate                     scheduled for    390.000 @  A32  process=load
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-5a31fec69194> in <module>
#      30 payingBooth_island = PayingBooth(location="island")
#      31
# ---> 32 env.run(duration=SIM_TIME)
#      33 print()
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/salabim/salabim.py in run(self, duration, till, priority, urgent)
#    5675                 self.do_simulate_and_animate()
#    5676             else:
# -> 5677                 self.do_simulate()
#    5678         if self.stopped:
#    5679             self.quit()
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/salabim/salabim.py in do_simulate(self)
#    5683             pass
#    5684         while self.running and not self._animate:
# -> 5685             self.step()
#    5686
#    5687     def do_simulate_and_animate(self):
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/salabim/salabim.py in step(self)
#    4316                     self._terminate(c)
#    4317             else:
# -> 4318                 c._process(**c._process_kwargs)
#    4319                 self._terminate(c)
#    4320         except Exception:
#
# <ipython-input-6-bd323060af8b> in process(self)
#      41         while True:
#      42             # Load the ferry
# ---> 43             CanadianFerry.activate(process='load')
#      44
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/salabim/salabim.py in activate(self, at, delay, priority, urgent, process, keep_request, keep_wait, mode, **kwargs)
#   11429             scheduled_time = at + self.env._offset + delay
#   11430
# > 11431         self._reschedule(scheduled_time, priority, urgent, "activate", extra=extra)
#   11432
#   11433     def hold(self, duration=None, till=None, priority=0, urgent=False, mode=None):
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/salabim/salabim.py in _reschedule(self, scheduled_time, priority, urgent, caller, extra, s0)
#   11293                     extra,
#   11294                 ),
# > 11295                 s0=s0,
#   11296             )
#   11297
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/salabim/salabim.py in print_trace(self, s1, s2, s3, s4, s0, _optional)
#    6880                         #                                break
#    6881
# -> 6882                         s0 = self._frame_to_lineno(_get_caller_frame())
#    6883                 self.last_s0 = s0
#    6884                 line = pad(s0, 7) + pad(s1, 10) + " " + pad(s2, 20) + " " + pad(s3, max(len(s3), 36)) + " " + s4.strip()
#
# /Applications/Anaconda/anaconda3/lib/python3.7/site-packages/salabim/salabim.py in _get_caller_frame()
#   17155     stack = inspect.stack()
#   17156     filename0 = inspect.getframeinfo(stack[0][0]).filename
# > 17157     for i in range(len(inspect.stack())):
#   17158         frame = stack[i][0]
#   17159         if filename0 != inspect.getframeinfo(frame).filename:
#
# /Applications/Anaconda/anaconda3/lib/python3.7/inspect.py in stack(context)
#    1511 def stack(context=1):
#    1512     """Return a list of records for the stack above the caller's frame."""
# -> 1513     return getouterframes(sys._getframe(1), context)
#    1514
#    1515 def trace(context=1):
#
# /Applications/Anaconda/anaconda3/lib/python3.7/inspect.py in getouterframes(frame, context)
#    1488     framelist = []
#    1489     while frame:
# -> 1490         frameinfo = (frame,) + getframeinfo(frame, context)
#    1491         framelist.append(FrameInfo(*frameinfo))
#    1492         frame = frame.f_back
#
# /Applications/Anaconda/anaconda3/lib/python3.7/inspect.py in getframeinfo(frame, context)
#    1462         start = lineno - 1 - context//2
#    1463         try:
# -> 1464             lines, lnum = findsource(frame)
#    1465         except OSError:
#    1466             lines = index = None
#
# /Applications/Anaconda/anaconda3/lib/python3.7/inspect.py in findsource(object)
#     778             raise OSError('source code not available')
#     779
# --> 780     module = getmodule(object, file)
#     781     if module:
#     782         lines = linecache.getlines(file, module.__dict__)
#
# /Applications/Anaconda/anaconda3/lib/python3.7/inspect.py in getmodule(object, _filename)
#     731     # Copy sys.modules in order to cope with changes while iterating
#     732     for modname, module in sys.modules.copy().items():
# --> 733         if ismodule(module) and hasattr(module, '__file__'):
#     734             f = module.__file__
#     735             if f == _filesbymodname.get(modname, None):
#
# KeyboardInterrupt:

# %%
island_line1.print_statistics()
