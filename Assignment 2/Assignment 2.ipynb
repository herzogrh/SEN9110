# %%
import salabim as sim
import numpy as np
import pandas as pd
import time, sys, random, os

# %%
CAR_NUMBERS = pd.read_csv("TimeTable.csv", sep=";")

SAILING_TIME = sim.Triangular(10,18,13)
NUMBER_OF_CARS = sim.Triangular(70,80,75)
PAYMENT_TIME = sim.Triangular(1,4,2)
LOADING_TIME = sim.Exponential(1/6) # 10 seconds per car
UNLOADING_TIME = sim.Exponential(5/60) # 5 seconds per time
WAITING_TIME_PREPAID = sim.Exponential(0.5) # minutes
PERCENTAGE_PREPAID = 0.2 

SIM_TIME = 60*24 # Time in minutes
REPLICATIONS = 10 # Number of experiment replications
ANIMATION = True
ANIMATION_TIME_CAR = 5
TRACE = True

# %%
class Car(sim.Component):
    def setup(self, cartype, paid, location):
        self.cartype = cartype # either tourist or employee
        self.paid = paid # true for prepaid, false for not prepaid
        self.location = location # either mainland or island
        self.inittime = env.now() # get the time the car was instantiated

    def process(self):  
        # Go to the assigned booth and line depending on the cartype, prepaid and locations
        ## Employee type
        if self.cartype == "employee":
            if self.location == "mainland":
                if ANIMATION:
                        sim.Animate(image="employee_car_mainland.png", t1=env.now()+ANIMATION_TIME_CAR, x0=50, y0=400, x1=75, alpha1=0)
                self.enter(mainland_line1)
                
            else: 
                if ANIMATION:
                        sim.Animate(image="employee_car_island.png", t1=env.now()+ANIMATION_TIME_CAR, x0=900, y0=400, x1=875, alpha1=0)
                self.enter(island_line1)
                
        ## Tourists
        else: 
            # In case the tourist has prepaid 
            if self.paid:
                if self.location == "mainland":

                    # Animate
                    if ANIMATION:
                        sim.Animate(image="tourist_car_mainland.png", t1=env.now()+ANIMATION_TIME_CAR, x0=50, y0=250, x1=75, alpha1=0)

                    # Wait until the prepaid booth is free
                    yield self.request(prepaid_booth_mainland)

                    # Do the 
                    yield self.hold(WAITING_TIME_PREPAID.sample())

                    # Free up the prepaid booth
                    self.release(prepaid_booth_mainland) 

                    # Enter the assigned waiting line
                    self.enter(mainland_line2)

                # Same for the island
                else: 
                    if ANIMATION:
                        sim.Animate(image="tourist_car_island.png", t1=env.now()+ANIMATION_TIME_CAR, x0=900, y0=250, x1=875, alpha1=0)
                    yield self.request(prepaid_booth_island)
                    yield self.hold(WAITING_TIME_PREPAID.sample())
                    self.release(prepaid_booth_island) 
                    self.enter(island_line2)

            # In case the tourist still has to pay
            else: 
                if self.location == "mainland":
                    if ANIMATION:
                        sim.Animate(image="tourist_car_mainland.png", t1=env.now()+ANIMATION_TIME_CAR, x0=50, y0=100, x1=75, alpha1=0)
                    yield self.request(payment_booth_mainland)
                    yield self.hold(PAYMENT_TIME.sample())
                    self.release(payment_booth_mainland)
                    self.enter(mainland_line3)
                    
                    
                else: 
                    if ANIMATION:
                        sim.Animate(image="tourist_car_island.png", t1=env.now()+ANIMATION_TIME_CAR, x0=900, y0=100, x1=875, alpha1=0)
                    yield self.request(payment_booth_island)
                    yield self.hold(PAYMENT_TIME.sample())
                    self.release(payment_booth_island)
                    self.enter(island_line3)
                    
        # Passivate the component
        yield self.passivate()

    # Set waiting time tallies whenever a car enters the ferry
    def setTally(self):
        total_waiting_time = env.now() - self.inittime

        if self.cartype == "employee":
            Waitingtime_employee.tally(total_waiting_time)
        elif self.paid:
            Waitingtime_tourist_prepaid.tally(total_waiting_time)
        else:
            Waitingtime_tourist_unpaid.tally(total_waiting_time)

        yield self.passivate()

# %%
class CarGenerator(sim.Component):
    def setup(self, location, cartype):
        self.cartype = cartype # either tourist or employee
        self.location = location # either mainland or island

    def process(self):
        while True:
            #Get current time
            CurrentCarNumbers = CAR_NUMBERS[CAR_NUMBERS["time"]<= (env.now()/60)].tail(1)

            ## Get the number of cars
            number_cars = int(CurrentCarNumbers[str(self.cartype) + "_" + str(self.location)])

            ## Calculate the time span the cars arrive in 
            time_span = int(CAR_NUMBERS["time"].iloc[CurrentCarNumbers.index + 1]) - int(CAR_NUMBERS["time"].iloc[CurrentCarNumbers.index])

            ## Check if number of cars is greater than zero, then wait the correct amount of time, otherwise wait for the time interval
            if number_cars > 0:
                # Generate a car
                Car(cartype = self.cartype, paid = (random.random() < 0.2), location= self.location)

                # Wait for the correct amount of time until creating the next car
                # Interarrival times are based on an exponential equation
                yield self.hold(sim.Exponential(60*time_span / number_cars))
            else:
                yield self.hold(60*time_span)

# %%
class Ferry(sim.Component):
    def setup(self, capacity, carsonferry, ferryrides, location):
        self.capacity = capacity # indicates how much space there is on the ferry
        self.carsonferry = carsonferry # indicates how many cars there are currently on the ferry 
        self.ferryrides = ferryrides # counts the amount of ferryrides done
        self.location = location # the location of the ferry (either mainland or island)
    
    #Repetetive task of the ferry
    def process(self):
        while True: 
            yield from self.load()

            yield self.wait(departuretime, ferryloaded, all=True)

            yield from self.cruise()

            yield from self.unload()


    # Cruising process of the ferry
    def cruise(self):
        # Set the departure time to False
        departuretime.set(False)

        # Tally the Ferrydelay
        Ferrydelay.tally(env.now()-self.ferryrides*30+60*7)

        # Add one more ride to the ferry ride attribute
        self.ferryrides += 1

        # Cruise
        yield self.hold(SAILING_TIME.sample())

        # Change the location of the ferry
        if self.location == "mainland":
            self.location = "island"
        else:
            self.location = "mainland"
        

    # Loading process of the ferry
    def load(self):  
        # Determine the capacity
        self.capacity = NUMBER_OF_CARS.sample()

        # As long as there is space left, check the waiting lines and fill up the space
        while self.capacity > self.carsonferry:            
            # Check for departure 
            if departuretime.get():
                break
            
            # Check location
            if self.location == "mainland":
                # Check if there are any cars left in the queues 
                if len(mainland_line1) > 0:
                    self.car = mainland_line1.pop()
                    self.carsonferry += 1
                    yield self.hold(LOADING_TIME.sample())
                    self.car.activate(process='setTally')
                elif len(mainland_line2) > 0:
                    self.car = mainland_line2.pop()
                    self.carsonferry += 1
                    yield self.hold(LOADING_TIME.sample())
                    self.car.activate(process='setTally')
                elif len(mainland_line3) > 0:
                    self.car = mainland_line3.pop()
                    self.carsonferry += 1
                    yield self.hold(LOADING_TIME.sample())
                    self.car.activate(process='setTally')

                # If no cars are left, set the ferryloaded state to true and check again in 5 mins
                else:
                    ferryloaded.set(True)
                    yield self.hold(5)


            # Same goes for the Island
            if self.location == "island":
                if len(island_line1) > 0:
                    self.car = island_line1.pop()
                    self.carsonferry += 1
                    yield self.hold(LOADING_TIME.sample())
                    self.car.activate(process='setTally')
                elif len(island_line2) > 0:
                    self.car = island_line2.pop()
                    self.carsonferry += 1
                    yield self.hold(LOADING_TIME.sample())
                    self.car.activate(process='setTally')
                elif len(island_line3) > 0:
                    self.car = island_line3.pop()
                    self.carsonferry += 1
                    yield self.hold(LOADING_TIME.sample())
                    self.car.activate(process='setTally')
                else:
                    ferryloaded.set(True)
                    yield self.hold(5)

        # When the maximum capacity is reached, set the ferry to loaded
        ferryloaded.set(True)

    # Unloading of the ferry
    def unload(self):
        for i in range(self.carsonferry):
            yield self.hold(UNLOADING_TIME.sample())
        self.carsonferry = 0
        ferryloaded.set(False)

# %%
class FerryOperator(sim.Component):
    def process(self):
        while True:
            # Load the ferry       
            CanadianFerry.activate()

            # Wait for 30 mins
            yield self.hold(30)

            # Give the go for departure
            departuretime.set(True)

# %%
class BoothOperator(sim.Component):
    def process(self):
        # Add an additional booth to the Mainland when initiated on 9:00
        payment_booth_mainland.set_capacity(2)

        # Remove the additional booth again on 12:00
        yield self.hold(3*60)
        payment_booth_mainland.set_capacity(1)

        # Add an additional booth on the island on 15:00
        yield self.hold(3*60)
        payment_booth_island.set_capacity(2)

        # Remove the additional booth on 17:00
        yield self.hold(2*60)
        payment_booth_island.set_capacity(1)

        # Passivate
        yield self.passivate()

# %%
# Animation code
def do_animation():
    if ANIMATION: 
        # Enable animation
        env.animate(True)

        env.background_color('20%gray')

        # Mainland queues
        qm1 = sim.AnimateQueue(mainland_line1, x=100, y=400, title='Mainland line 1 - Employees', direction='e', id='green', max_length=5)
        qm2 = sim.AnimateQueue(mainland_line2, x=100, y=250, title='Mainland line 2 - Tourists prepaid', direction='e', id='green', max_length=5)
        qm3 = sim.AnimateQueue(mainland_line3, x=100, y=100, title='Mainland line 3 - Tourists', direction='e', id='green', max_length=5)

        # Mainland queues
        qm1 = sim.AnimateQueue(island_line1, x=800, y=400, title='Island line 1 - Employees', direction='w', id='blue', max_length=5)
        qm2 = sim.AnimateQueue(island_line2, x=800, y=250, title='Island line 2 - Tourists prepaid', direction='w', id='blue', max_length=5)
        qm3 = sim.AnimateQueue(island_line3, x=800, y=100, title='Island line 3 - Tourists', direction='w', id='blue', max_length=5)
    else:
        env.animate(False)

    #sim.AnimateMonitor(Waitingtime_tourist_prepaid, x=1000, y=100)

# %%
# Create the Environment
env = sim.Environment(time_unit='minutes', trace= TRACE)
env.modelname("Canadian Ferries Simulation")

# States
departuretime = sim.State('departuretime', value=False)
ferryloaded = sim.State('ferryloaded', value=False)

# Queues
mainland_line1, mainland_line2, mainland_line3 = sim.Queue('mainland_line1'), sim.Queue('mainland_line2'), sim.Queue('mainland_line3')
island_line1, island_line2, island_line3 = sim.Queue('island_line1'), sim.Queue('island_line2'), sim.Queue('island_line3')
mainland_line2_1, mainland_line3_1 = sim.Queue('mainland_line2_1'), sim.Queue('mainland_line3_1')
island_line2_1, island_line3_1 = sim.Queue('island_line2_1'), sim.Queue('island_line3_1')

# Create a ferry at the beginning of the simulation
CanadianFerry = Ferry(capacity = NUMBER_OF_CARS.sample(), carsonferry = 0, ferryrides = 0, location = "mainland")

# Activate the Ferry operators on 6:30
FerryOperator(at=6.5*60)

# Activate the Booth operator on 9:00
BoothOperator(at=9*60)

# Initiate the Car Generators
CarGenerator(cartype="employee", location="island")
CarGenerator(cartype="employee", location="mainland")
CarGenerator(cartype="tourist", location="island")
CarGenerator(cartype="tourist", location="mainland")

# Resources
payment_booth_mainland = sim.Resource('payment_booth_mainland', capacity=1)
payment_booth_island = sim.Resource('payment_booth_island', capacity=1)
prepaid_booth_mainland = sim.Resource('prepaid_booth_mainland', capacity=1)
prepaid_booth_island = sim.Resource('prepaid_booth_island', capacity=1)

# Monitors
Waitingtime_tourist_prepaid = sim.Monitor('Waitingtime_tourist_prepaid') #tally
Waitingtime_tourist_unpaid = sim.Monitor('Waitingtime_tourist_unpaid') #tally
Waitingtime_employee = sim.Monitor('Waitingtime_employee') #tally

Ferrydelay = sim.Monitor(name='Ferrydelay', level=True, initial_tally=0)

# Calls the function which has all the animation code in
do_animation()

# Run the experiments
env.run(duration=SIM_TIME)
# Out:
# line#        time current component    action                               information
# ------ ---------- -------------------- -----------------------------------  ------------------------------------------------
#                                        line numbers refers to               <ipython-input-9-6a2642c6e656>
#     2                                  default environment initialize
#     2                                  main create
#     2       0.000 main                 current
#     6                                  departuretime create                 value= False
#     7                                  ferryloaded create                   value= False
#    10                                  mainland_line1 create
#    10                                  mainland_line2 create
#    10                                  mainland_line3 create
#    11                                  island_line1 create
#    11                                  island_line2 create
#    11                                  island_line3 create
#    12                                  mainland_line2_1 create
#    12                                  mainland_line3_1 create
#    13                                  island_line2_1 create
#    13                                  island_line3_1 create
#    16                                  ferry.0 create
#                                        line numbers prefixed by A refer to  <ipython-input-5-526af3e4eaf6>
#    16                                  ferry.0 activate                     scheduled for      0.000 @   A9  process=process
#    19                                  ferryoperator.0 create
#                                        line numbers prefixed by B refer to  <ipython-input-6-8683104522fb>
#    19                                  ferryoperator.0 activate +390.000    scheduled for    390.000 @   B2  process=process
#    22                                  boothoperator.0 create
#                                        line numbers prefixed by C refer to  <ipython-input-7-04d1429e8568>
#    22                                  boothoperator.0 activate +540.000    scheduled for    540.000 @   C2  process=process
#    25                                  cargenerator.0 create
#                                        line numbers prefixed by D refer to  <ipython-input-4-38a831aa6665>
#    25                                  cargenerator.0 activate              scheduled for      0.000 @   D6  process=process
#    26                                  cargenerator.1 create
#    26                                  cargenerator.1 activate              scheduled for      0.000 @   D6  process=process
#    27                                  cargenerator.2 create
#    27                                  cargenerator.2 activate              scheduled for      0.000 @   D6  process=process
#    28                                  cargenerator.3 create
#    28                                  cargenerator.3 activate              scheduled for      0.000 @   D6  process=process
#    31                                  payment_booth_mainland create        capacity=1
#    32                                  payment_booth_island create          capacity=1
#    33                                  prepaid_booth_mainland create        capacity=1
#    34                                  prepaid_booth_island create          capacity=1
#    45                                  main run +1440.000                   scheduled for   1440.000 @   45+
#    A9       0.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for      5.000 @  A11+
#    D6       0.000 cargenerator.0       current
#   D26                                  cargenerator.0 hold +360.000         scheduled for    360.000 @  D26+
#    D6       0.000 cargenerator.1       current
#   D26                                  cargenerator.1 hold +360.000         scheduled for    360.000 @  D26+
#    D6       0.000 cargenerator.2       current
#   D26                                  cargenerator.2 hold +360.000         scheduled for    360.000 @  D26+
#    D6       0.000 cargenerator.3       current
#   D26                                  cargenerator.3 hold +360.000         scheduled for    360.000 @  D26+
#   A11+      5.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     10.000 @  A11+
#   A11+     10.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     15.000 @  A11+
#   A11+     15.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     20.000 @  A11+
#   A11+     20.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     25.000 @  A11+
#   A11+     25.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     30.000 @  A11+
#   A11+     30.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     35.000 @  A11+
#   A11+     35.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     40.000 @  A11+
#   A11+     40.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     45.000 @  A11+
#   A11+     45.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     50.000 @  A11+
#   A11+     50.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     55.000 @  A11+
#   A11+     55.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     60.000 @  A11+
#   A11+     60.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     65.000 @  A11+
#   A11+     65.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     70.000 @  A11+
#   A11+     70.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     75.000 @  A11+
#   A11+     75.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     80.000 @  A11+
#   A11+     80.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     85.000 @  A11+
#   A11+     85.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     90.000 @  A11+
#   A11+     90.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for     95.000 @  A11+
#   A11+     95.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    100.000 @  A11+
#   A11+    100.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    105.000 @  A11+
#   A11+    105.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    110.000 @  A11+
#   A11+    110.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    115.000 @  A11+
#   A11+    115.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    120.000 @  A11+
#   A11+    120.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    125.000 @  A11+
#   A11+    125.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    130.000 @  A11+
#   A11+    130.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    135.000 @  A11+
#   A11+    135.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    140.000 @  A11+
#   A11+    140.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    145.000 @  A11+
#   A11+    145.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    150.000 @  A11+
#   A11+    150.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    155.000 @  A11+
#   A11+    155.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    160.000 @  A11+
#   A11+    160.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    165.000 @  A11+
#   A11+    165.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    170.000 @  A11+
#   A11+    170.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    175.000 @  A11+
#   A11+    175.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    180.000 @  A11+
#   A11+    180.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    185.000 @  A11+
#   A11+    185.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    190.000 @  A11+
#   A11+    190.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    195.000 @  A11+
#   A11+    195.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    200.000 @  A11+
#   A11+    200.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    205.000 @  A11+
#   A11+    205.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    210.000 @  A11+
#   A11+    210.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    215.000 @  A11+
#   A11+    215.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    220.000 @  A11+
#   A11+    220.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    225.000 @  A11+
#   A11+    225.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    230.000 @  A11+
#   A11+    230.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    235.000 @  A11+
#   A11+    235.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    240.000 @  A11+
#   A11+    240.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    245.000 @  A11+
#   A11+    245.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    250.000 @  A11+
#   A11+    250.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    255.000 @  A11+
#   A11+    255.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    260.000 @  A11+
#   A11+    260.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    265.000 @  A11+
#   A11+    265.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    270.000 @  A11+
#   A11+    270.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    275.000 @  A11+
#   A11+    275.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    280.000 @  A11+
#   A11+    280.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    285.000 @  A11+
#   A11+    285.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    290.000 @  A11+
#   A11+    290.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    295.000 @  A11+
#   A11+    295.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    300.000 @  A11+
#   A11+    300.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    305.000 @  A11+
#   A11+    305.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    310.000 @  A11+
#   A11+    310.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    315.000 @  A11+
#   A11+    315.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    320.000 @  A11+
#   A11+    320.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    325.000 @  A11+
#   A11+    325.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    330.000 @  A11+
#   A11+    330.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    335.000 @  A11+
#   A11+    335.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    340.000 @  A11+
#   A11+    340.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    345.000 @  A11+
#   A11+    345.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    350.000 @  A11+
#   A11+    350.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    355.000 @  A11+
#   A11+    355.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    360.000 @  A11+
#   D26+    360.000 cargenerator.0       current
#   D20                                  car.0 create
#                                        line numbers prefixed by E refer to  <ipython-input-3-0c5355e786af>
#   D20                                  car.0 activate                       scheduled for    360.000 @   E8  process=process
#   D24                                  cargenerator.0 hold +2.104           scheduled for    362.104 @  D24+
#   D26+    360.000 cargenerator.1       current
#   D20                                  car.1 create
#   D20                                  car.1 activate                       scheduled for    360.000 @   E8  process=process
#   D24                                  cargenerator.1 hold +4.863           scheduled for    364.863 @  D24+
#   D26+    360.000 cargenerator.2       current
#   D20                                  car.2 create
#   D20                                  car.2 activate                       scheduled for    360.000 @   E8  process=process
#   D24                                  cargenerator.2 hold +68.767          scheduled for    428.767 @  D24+
#   D26+    360.000 cargenerator.3       current
#   D20                                  car.3 create
#   D20                                  car.3 activate                       scheduled for    360.000 @   E8  process=process
#   D24                                  cargenerator.3 hold +34.593          scheduled for    394.593 @  D24+
#   A11+    360.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    365.000 @  A11+
#    E8     360.000 car.0                current
#   E20                                  car.0                                enter island_line1
#   E73                                  car.0 passivate
#    E8     360.000 car.1                current
#   E15                                  car.1                                enter mainland_line1
#   E73                                  car.1 passivate
#    E8     360.000 car.2                current
#   E48                                  car.2                                request 1 from prepaid_booth_island priority=inf
#   E48                                  car.2                                claim 1 from prepaid_booth_island priority=inf
#   E48                                  car.2 request honor prepaid_booth_island scheduled for    360.000 @  E48+
#    E8     360.000 car.3                current
#   E58                                  car.3                                request 1 from payment_booth_mainland priority=inf
#   E58                                  car.3                                claim 1 from payment_booth_mainland priority=inf
#   E58                                  car.3 request honor payment_booth_mainland scheduled for    360.000 @  E58+
#   E48+    360.000 car.2                current
#   E49                                  car.2 hold +0.875                    scheduled for    360.875 @  E49+
#   E58+    360.000 car.3                current
#   E59                                  car.3 hold +1.725                    scheduled for    361.725 @  E59+
#   E49+    360.875 car.2                current
#   E50                                  car.2                                release 1 from prepaid_booth_island
#   E51                                  car.2                                enter island_line2
#   E73                                  car.2 passivate
#   E59+    361.725 car.3                current
#   E60                                  car.3                                release 1 from payment_booth_mainland
#   E61                                  car.3                                enter mainland_line3
#   E73                                  car.3 passivate
#   D24+    362.104 cargenerator.0       current
#   D20                                  car.4 create
#   D20                                  car.4 activate                       scheduled for    362.104 @   E8  process=process
#   D24                                  cargenerator.0 hold +13.080          scheduled for    375.184 @  D24+
#    E8     362.104 car.4                current
#   E20                                  car.4                                enter island_line1
#   E73                                  car.4 passivate
#   D24+    364.863 cargenerator.1       current
#   D20                                  car.5 create
#   D20                                  car.5 activate                       scheduled for    364.863 @   E8  process=process
#   D24                                  cargenerator.1 hold +4.051           scheduled for    368.914 @  D24+
#    E8     364.863 car.5                current
#   E15                                  car.5                                enter mainland_line1
#   E73                                  car.5 passivate
#   A11+    365.000 ferry.0              current
#   A53                                  car.1                                leave mainland_line1
#   A55                                  ferry.0 hold +0.049                  scheduled for    365.049 @  A11+
#   A11+    365.049 ferry.0              current
#   A56                                  car.1 activate                       scheduled for    365.049 @  E76  process=setTally
#   A53                                  car.5                                leave mainland_line1
#   A55                                  ferry.0 hold +0.071                  scheduled for    365.120 @  A11+
#   E76     365.049 car.1                current
#   E86                                  car.1 passivate
#   A11+    365.120 ferry.0              current
#   A56                                  car.5 activate                       scheduled for    365.120 @  E76  process=setTally
#   A63                                  car.3                                leave mainland_line3
#   A65                                  ferry.0 hold +0.102                  scheduled for    365.222 @  A11+
#   E76     365.120 car.5                current
#   E86                                  car.5 passivate
#   A11+    365.222 ferry.0              current
#   A66                                  car.3 activate                       scheduled for    365.222 @  E76  process=setTally
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    370.222 @  A11+
#   E76     365.222 car.3                current
#   E86                                  car.3 passivate
#   D24+    368.914 cargenerator.1       current
#   D20                                  car.6 create
#   D20                                  car.6 activate                       scheduled for    368.914 @   E8  process=process
#   D24                                  cargenerator.1 hold +7.077           scheduled for    375.991 @  D24+
#    E8     368.914 car.6                current
#   E15                                  car.6                                enter mainland_line1
#   E73                                  car.6 passivate
#   A11+    370.222 ferry.0              current
#   A53                                  car.6                                leave mainland_line1
#   A55                                  ferry.0 hold +0.205                  scheduled for    370.427 @  A11+
#   A11+    370.427 ferry.0              current
#   A56                                  car.6 activate                       scheduled for    370.427 @  E76  process=setTally
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    375.427 @  A11+
#   E76     370.427 car.6                current
#   E86                                  car.6 passivate
#   D24+    375.184 cargenerator.0       current
#   D20                                  car.7 create
#   D20                                  car.7 activate                       scheduled for    375.184 @   E8  process=process
#   D24                                  cargenerator.0 hold +6.608           scheduled for    381.792 @  D24+
#    E8     375.184 car.7                current
#   E20                                  car.7                                enter island_line1
#   E73                                  car.7 passivate
#   A11+    375.427 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    380.427 @  A11+
#   D24+    375.991 cargenerator.1       current
#   D20                                  car.8 create
#   D20                                  car.8 activate                       scheduled for    375.991 @   E8  process=process
#   D24                                  cargenerator.1 hold +1.255           scheduled for    377.245 @  D24+
#    E8     375.991 car.8                current
#   E15                                  car.8                                enter mainland_line1
#   E73                                  car.8 passivate
#   D24+    377.245 cargenerator.1       current
#   D20                                  car.9 create
#   D20                                  car.9 activate                       scheduled for    377.245 @   E8  process=process
#   D24                                  cargenerator.1 hold +3.567           scheduled for    380.812 @  D24+
#    E8     377.245 car.9                current
#   E15                                  car.9                                enter mainland_line1
#   E73                                  car.9 passivate
#   A11+    380.427 ferry.0              current
#   A53                                  car.8                                leave mainland_line1
#   A55                                  ferry.0 hold +0.117                  scheduled for    380.543 @  A11+
#   A11+    380.543 ferry.0              current
#   A56                                  car.8 activate                       scheduled for    380.543 @  E76  process=setTally
#   A53                                  car.9                                leave mainland_line1
#   A55                                  ferry.0 hold +0.287                  scheduled for    380.830 @  A11+
#   E76     380.543 car.8                current
#   E86                                  car.8 passivate
#   D24+    380.812 cargenerator.1       current
#   D20                                  car.10 create
#   D20                                  car.10 activate                      scheduled for    380.812 @   E8  process=process
#   D24                                  cargenerator.1 hold +10.419          scheduled for    391.231 @  D24+
#    E8     380.812 car.10               current
#   E15                                  car.10                               enter mainland_line1
#   E73                                  car.10 passivate
#   A11+    380.830 ferry.0              current
#   A56                                  car.9 activate                       scheduled for    380.830 @  E76  process=setTally
#   A53                                  car.10                               leave mainland_line1
#   A55                                  ferry.0 hold +0.007                  scheduled for    380.837 @  A11+
#   E76     380.830 car.9                current
#   E86                                  car.9 passivate
#   A11+    380.837 ferry.0              current
#   A56                                  car.10 activate                      scheduled for    380.837 @  E76  process=setTally
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    385.837 @  A11+
#   E76     380.837 car.10               current
#   E86                                  car.10 passivate
#   D24+    381.792 cargenerator.0       current
#   D20                                  car.11 create
#   D20                                  car.11 activate                      scheduled for    381.792 @   E8  process=process
#   D24                                  cargenerator.0 hold +5.243           scheduled for    387.035 @  D24+
#    E8     381.792 car.11               current
#   E20                                  car.11                               enter island_line1
#   E73                                  car.11 passivate
#   A11+    385.837 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    390.837 @  A11+
#   D24+    387.035 cargenerator.0       current
#   D20                                  car.12 create
#   D20                                  car.12 activate                      scheduled for    387.035 @   E8  process=process
#   D24                                  cargenerator.0 hold +4.942           scheduled for    391.977 @  D24+
#    E8     387.035 car.12               current
#   E20                                  car.12                               enter island_line1
#   E73                                  car.12 passivate
#    B2     390.000 ferryoperator.0      current
#    B5                                  ferry.0 activate                     scheduled for    390.000 @  A11+
#    B8                                  ferryoperator.0 hold +30.000         scheduled for    420.000 @   B8+
#   A11+    390.000 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    395.000 @  A11+
#   D24+    391.231 cargenerator.1       current
#   D20                                  car.13 create
#   D20                                  car.13 activate                      scheduled for    391.231 @   E8  process=process
#   D24                                  cargenerator.1 hold +4.383           scheduled for    395.614 @  D24+
#    E8     391.231 car.13               current
#   E15                                  car.13                               enter mainland_line1
#   E73                                  car.13 passivate
#   D24+    391.977 cargenerator.0       current
#   D20                                  car.14 create
#   D20                                  car.14 activate                      scheduled for    391.977 @   E8  process=process
#   D24                                  cargenerator.0 hold +4.893           scheduled for    396.870 @  D24+
#    E8     391.977 car.14               current
#   E20                                  car.14                               enter island_line1
#   E73                                  car.14 passivate
#   D24+    394.593 cargenerator.3       current
#   D20                                  car.15 create
#   D20                                  car.15 activate                      scheduled for    394.593 @   E8  process=process
#   D24                                  cargenerator.3 hold +14.979          scheduled for    409.571 @  D24+
#    E8     394.593 car.15               current
#   E33                                  car.15                               request 1 from prepaid_booth_mainland priority=inf
#   E33                                  car.15                               claim 1 from prepaid_booth_mainland priority=inf
#   E33                                  car.15 request honor prepaid_booth_mainland scheduled for    394.593 @  E33+
#   E33+    394.593 car.15               current
#   E36                                  car.15 hold +0.851                   scheduled for    395.443 @  E36+
#   A11+    395.000 ferry.0              current
#   A53                                  car.13                               leave mainland_line1
#   A55                                  ferry.0 hold +0.117                  scheduled for    395.117 @  A11+
#   A11+    395.117 ferry.0              current
#   A56                                  car.13 activate                      scheduled for    395.117 @  E76  process=setTally
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    400.117 @  A11+
#   E76     395.117 car.13               current
#   E86                                  car.13 passivate
#   E36+    395.443 car.15               current
#   E39                                  car.15                               release 1 from prepaid_booth_mainland
#   E42                                  car.15                               enter mainland_line2
#   E73                                  car.15 passivate
#   D24+    395.614 cargenerator.1       current
#   D20                                  car.16 create
#   D20                                  car.16 activate                      scheduled for    395.614 @   E8  process=process
#   D24                                  cargenerator.1 hold +0.792           scheduled for    396.406 @  D24+
#    E8     395.614 car.16               current
#   E15                                  car.16                               enter mainland_line1
#   E73                                  car.16 passivate
#   D24+    396.406 cargenerator.1       current
#   D20                                  car.17 create
#   D20                                  car.17 activate                      scheduled for    396.406 @   E8  process=process
#   D24                                  cargenerator.1 hold +0.558           scheduled for    396.964 @  D24+
#    E8     396.406 car.17               current
#   E15                                  car.17                               enter mainland_line1
#   E73                                  car.17 passivate
#   D24+    396.870 cargenerator.0       current
#   D20                                  car.18 create
#   D20                                  car.18 activate                      scheduled for    396.870 @   E8  process=process
#   D24                                  cargenerator.0 hold +39.508          scheduled for    436.378 @  D24+
#    E8     396.870 car.18               current
#   E20                                  car.18                               enter island_line1
#   E73                                  car.18 passivate
#   D24+    396.964 cargenerator.1       current
#   D20                                  car.19 create
#   D20                                  car.19 activate                      scheduled for    396.964 @   E8  process=process
#   D24                                  cargenerator.1 hold +8.696           scheduled for    405.660 @  D24+
#    E8     396.964 car.19               current
#   E15                                  car.19                               enter mainland_line1
#   E73                                  car.19 passivate
#   A11+    400.117 ferry.0              current
#   A53                                  car.16                               leave mainland_line1
#   A55                                  ferry.0 hold +0.003                  scheduled for    400.121 @  A11+
#   A11+    400.121 ferry.0              current
#   A56                                  car.16 activate                      scheduled for    400.121 @  E76  process=setTally
#   A53                                  car.17                               leave mainland_line1
#   A55                                  ferry.0 hold +0.005                  scheduled for    400.126 @  A11+
#   E76     400.121 car.16               current
#   E86                                  car.16 passivate
#   A11+    400.126 ferry.0              current
#   A56                                  car.17 activate                      scheduled for    400.126 @  E76  process=setTally
#   A53                                  car.19                               leave mainland_line1
#   A55                                  ferry.0 hold +0.034                  scheduled for    400.160 @  A11+
#   E76     400.126 car.17               current
#   E86                                  car.17 passivate
#   A11+    400.160 ferry.0              current
#   A56                                  car.19 activate                      scheduled for    400.160 @  E76  process=setTally
#   A58                                  car.15                               leave mainland_line2
#   A60                                  ferry.0 hold +0.325                  scheduled for    400.485 @  A11+
#   E76     400.160 car.19               current
#   E86                                  car.19 passivate
#   A11+    400.485 ferry.0              current
#   A61                                  car.15 activate                      scheduled for    400.485 @  E76  process=setTally
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    405.485 @  A11+
#   E76     400.485 car.15               current
#   E86                                  car.15 passivate
#   A11+    405.485 ferry.0              current
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    410.485 @  A11+
#   D24+    405.660 cargenerator.1       current
#   D20                                  car.20 create
#   D20                                  car.20 activate                      scheduled for    405.660 @   E8  process=process
#   D24                                  cargenerator.1 hold +0.843           scheduled for    406.503 @  D24+
#    E8     405.660 car.20               current
#   E15                                  car.20                               enter mainland_line1
#   E73                                  car.20 passivate
#   D24+    406.503 cargenerator.1       current
#   D20                                  car.21 create
#   D20                                  car.21 activate                      scheduled for    406.503 @   E8  process=process
#   D24                                  cargenerator.1 hold +4.448           scheduled for    410.951 @  D24+
#    E8     406.503 car.21               current
#   E15                                  car.21                               enter mainland_line1
#   E73                                  car.21 passivate
#   D24+    409.571 cargenerator.3       current
#   D20                                  car.22 create
#   D20                                  car.22 activate                      scheduled for    409.571 @   E8  process=process
#   D24                                  cargenerator.3 hold +0.410           scheduled for    409.981 @  D24+
#    E8     409.571 car.22               current
#   E33                                  car.22                               request 1 from prepaid_booth_mainland priority=inf
#   E33                                  car.22                               claim 1 from prepaid_booth_mainland priority=inf
#   E33                                  car.22 request honor prepaid_booth_mainland scheduled for    409.571 @  E33+
#   E33+    409.571 car.22               current
#   E36                                  car.22 hold +0.107                   scheduled for    409.678 @  E36+
#   E36+    409.678 car.22               current
#   E39                                  car.22                               release 1 from prepaid_booth_mainland
#   E42                                  car.22                               enter mainland_line2
#   E73                                  car.22 passivate
#   D24+    409.981 cargenerator.3       current
#   D20                                  car.23 create
#   D20                                  car.23 activate                      scheduled for    409.981 @   E8  process=process
#   D24                                  cargenerator.3 hold +54.146          scheduled for    464.127 @  D24+
#    E8     409.981 car.23               current
#   E58                                  car.23                               request 1 from payment_booth_mainland priority=inf
#   E58                                  car.23                               claim 1 from payment_booth_mainland priority=inf
#   E58                                  car.23 request honor payment_booth_mainland scheduled for    409.981 @  E58+
#   E58+    409.981 car.23               current
#   E59                                  car.23 hold +1.787                   scheduled for    411.768 @  E59+
#   A11+    410.485 ferry.0              current
#   A53                                  car.20                               leave mainland_line1
#   A55                                  ferry.0 hold +0.103                  scheduled for    410.588 @  A11+
#   A11+    410.588 ferry.0              current
#   A56                                  car.20 activate                      scheduled for    410.588 @  E76  process=setTally
#   A53                                  car.21                               leave mainland_line1
#   A55                                  ferry.0 hold +0.155                  scheduled for    410.743 @  A11+
#   E76     410.588 car.20               current
#   E86                                  car.20 passivate
#   A11+    410.743 ferry.0              current
#   A56                                  car.21 activate                      scheduled for    410.743 @  E76  process=setTally
#   A58                                  car.22                               leave mainland_line2
#   A60                                  ferry.0 hold +0.454                  scheduled for    411.197 @  A11+
#   E76     410.743 car.21               current
#   E86                                  car.21 passivate
#   D24+    410.951 cargenerator.1       current
#   D20                                  car.24 create
#   D20                                  car.24 activate                      scheduled for    410.951 @   E8  process=process
#   D24                                  cargenerator.1 hold +4.321           scheduled for    415.272 @  D24+
#    E8     410.951 car.24               current
#   E15                                  car.24                               enter mainland_line1
#   E73                                  car.24 passivate
#   A11+    411.197 ferry.0              current
#   A61                                  car.22 activate                      scheduled for    411.197 @  E76  process=setTally
#   A53                                  car.24                               leave mainland_line1
#   A55                                  ferry.0 hold +0.089                  scheduled for    411.286 @  A11+
#   E76     411.197 car.22               current
#   E86                                  car.22 passivate
#   A11+    411.286 ferry.0              current
#   A56                                  car.24 activate                      scheduled for    411.286 @  E76  process=setTally
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    416.286 @  A11+
#   E76     411.286 car.24               current
#   E86                                  car.24 passivate
#   E59+    411.768 car.23               current
#   E60                                  car.23                               release 1 from payment_booth_mainland
#   E61                                  car.23                               enter mainland_line3
#   E73                                  car.23 passivate
#   D24+    415.272 cargenerator.1       current
#   D20                                  car.25 create
#   D20                                  car.25 activate                      scheduled for    415.272 @   E8  process=process
#   D24                                  cargenerator.1 hold +0.012           scheduled for    415.284 @  D24+
#    E8     415.272 car.25               current
#   E15                                  car.25                               enter mainland_line1
#   E73                                  car.25 passivate
#   D24+    415.284 cargenerator.1       current
#   D20                                  car.26 create
#   D20                                  car.26 activate                      scheduled for    415.284 @   E8  process=process
#   D24                                  cargenerator.1 hold +2.088           scheduled for    417.372 @  D24+
#    E8     415.284 car.26               current
#   E15                                  car.26                               enter mainland_line1
#   E73                                  car.26 passivate
#   A11+    416.286 ferry.0              current
#   A53                                  car.25                               leave mainland_line1
#   A55                                  ferry.0 hold +0.035                  scheduled for    416.321 @  A11+
#   A11+    416.321 ferry.0              current
#   A56                                  car.25 activate                      scheduled for    416.321 @  E76  process=setTally
#   A53                                  car.26                               leave mainland_line1
#   A55                                  ferry.0 hold +0.175                  scheduled for    416.496 @  A11+
#   E76     416.321 car.25               current
#   E86                                  car.25 passivate
#   A11+    416.496 ferry.0              current
#   A56                                  car.26 activate                      scheduled for    416.496 @  E76  process=setTally
#   A63                                  car.23                               leave mainland_line3
#   A65                                  ferry.0 hold +0.449                  scheduled for    416.945 @  A11+
#   E76     416.496 car.26               current
#   E86                                  car.26 passivate
#   A11+    416.945 ferry.0              current
#   A66                                  car.23 activate                      scheduled for    416.945 @  E76  process=setTally
#   A70                                  ferryloaded set                      value = True
#   A71                                  ferry.0 hold +5.000                  scheduled for    421.945 @  A11+
#   E76     416.945 car.23               current
#   E86                                  car.23 passivate
#   D24+    417.372 cargenerator.1       current
#   D20                                  car.27 create
#   D20                                  car.27 activate                      scheduled for    417.372 @   E8  process=process
#   D24                                  cargenerator.1 hold +0.257           scheduled for    417.628 @  D24+
#    E8     417.372 car.27               current
#   E15                                  car.27                               enter mainland_line1
#   E73                                  car.27 passivate
#   D24+    417.628 cargenerator.1       current
#   D20                                  car.28 create
#   D20                                  car.28 activate                      scheduled for    417.628 @   E8  process=process
#   D24                                  cargenerator.1 hold +1.435           scheduled for    419.064 @  D24+
#    E8     417.628 car.28               current
#   E15                                  car.28                               enter mainland_line1
#   E73                                  car.28 passivate
#   D24+    419.064 cargenerator.1       current
#   D20                                  car.29 create
#   D20                                  car.29 activate                      scheduled for    419.064 @   E8  process=process
#   D24                                  cargenerator.1 hold +1.872           scheduled for    420.935 @  D24+
#    E8     419.064 car.29               current
#   E15                                  car.29                               enter mainland_line1
#   E73                                  car.29 passivate
#    B8+    420.000 ferryoperator.0      current
#   B11                                  departuretime set                    value = True
#    B5                                  ferry.0 activate                     scheduled for    420.000 @  A11+
#    B8                                  ferryoperator.0 hold +30.000         scheduled for    450.000 @   B8+
#   A11+    420.000 ferry.0              current
#   A96                                  ferryloaded set                      value = True
#   A96                                  ferry.0 wait honor                   scheduled for    420.000 @  A13+
#   A13+    420.000 ferry.0              current
#   A23                                  departuretime set                    value = False
#   A29                                  ferry.0 hold +15.864                 scheduled for    435.864 @  A15+
#   D24+    420.935 cargenerator.1       current
#   D20                                  car.30 create
#   D20                                  car.30 activate                      scheduled for    420.935 @   E8  process=process
#   D24                                  cargenerator.1 hold +5.353           scheduled for    426.288 @  D24+
#    E8     420.935 car.30               current
#   E15                                  car.30                               enter mainland_line1
#   E73                                  car.30 passivate

# %%
Waitingtime_employee.print_statistics()
# Out:
# Statistics of Waitingtime_employee at      1440
#                         all    excl.zero         zero
# -------------- ------------ ------------ ------------
# entries             139          139            0
# mean                 21.366       21.366
# std.deviation        19.325       19.325
#
# minimum               0.024        0.024
# median               14.197       14.197
# 90% percentile       46.163       46.163
# 95% percentile       48.455       48.455
# maximum              77.384       77.384

# %%
Waitingtime_tourist_prepaid.print_histograms()
# Out:
# Histogram of Waitingtime_tourist_prepaid
#                         all    excl.zero         zero
# -------------- ------------ ------------ ------------
# entries              39           39            0
# mean                 22.111       22.111
# std.deviation        17.223       17.223
#
# minimum               1.625        1.625
# median               16.836       16.836
# 90% percentile       42.645       42.645
# 95% percentile       49.400       49.400
# maximum              78.677       78.677
#
#            <=       entries     %  cum%
#         0             0       0     0   |
#         5             7      17.9  17.9 **************|
#        10             4      10.3  28.2 ********              |
#        15             7      17.9  46.2 **************                      |
#        20             4      10.3  56.4 ********                                     |
#        25             1       2.6  59.0 **                                             |
#        30             4      10.3  69.2 ********                                               |
#        35             3       7.7  76.9 ******                                                       |
#        40             2       5.1  82.1 ****                                                             |
#        45             3       7.7  89.7 ******                                                                 |
#        50             2       5.1  94.9 ****                                                                       |
#        55             1       2.6  97.4 **                                                                           |
#        60             0       0    97.4                                                                              |
#        65             0       0    97.4                                                                              |
#        70             0       0    97.4                                                                              |
#        75             0       0    97.4                                                                              |
#        80             1       2.6 100   **                                                                              |
#           inf         0       0   100                                                                                   |

# %%
Waitingtime_tourist_unpaid.print_histograms()
# Out:
# Histogram of Waitingtime_tourist_unpaid
#                         all    excl.zero         zero
# -------------- ------------ ------------ ------------
# entries             184          184            0
# mean                 24.327       24.327
# std.deviation        15.267       15.267
#
# minimum               1.776        1.776
# median               22.753       22.753
# 90% percentile       45.214       45.214
# 95% percentile       48.102       48.102
# maximum              53.137       53.137
#
#            <=       entries     %  cum%
#         0             0       0     0   |
#         2             2       1.1   1.1 |
#         4            12       6.5   7.6 ***** |
#         6            11       6.0  13.6 ****      |
#         8            13       7.1  20.7 *****           |
#        10            11       6.0  26.6 ****                 |
#        12             7       3.8  30.4 ***                     |
#        14             7       3.8  34.2 ***                        |
#        16             5       2.7  37.0 **                           |
#        18             6       3.3  40.2 **                              |
#        20            10       5.4  45.7 ****                                |
#        22             7       3.8  49.5 ***                                    |
#        24             3       1.6  51.1 *                                       |
#        26             2       1.1  52.2                                          |
#        28             9       4.9  57.1 ***                                          |
#        30            10       5.4  62.5 ****                                              |
#        32             4       2.2  64.7 *                                                  |
#        34             5       2.7  67.4 **                                                   |
#        36             3       1.6  69.0 *                                                      |
#        38            11       6.0  75   ****                                                        |
#        40             6       3.3  78.3 **                                                            |
#        42             7       3.8  82.1 ***                                                              |
#        44             9       4.9  87.0 ***                                                                  |
#        46             8       4.3  91.3 ***                                                                      |
#        48             6       3.3  94.6 **                                                                         |
#        50             5       2.7  97.3 **                                                                           |
#        52             4       2.2  99.5 *                                                                              |
#        54             1       0.5 100                                                                                   |
#           inf         0       0   100                                                                                   |

# %%
Waitingtime_employee.print_histograms()
# Out:
# Histogram of Waitingtime_employee
#                         all    excl.zero         zero
# -------------- ------------ ------------ ------------
# entries             139          139            0
# mean                 21.366       21.366
# std.deviation        19.325       19.325
#
# minimum               0.024        0.024
# median               14.197       14.197
# 90% percentile       46.163       46.163
# 95% percentile       48.455       48.455
# maximum              77.384       77.384
#
#            <=       entries     %  cum%
#         0             0       0     0   |
#         5            51      36.7  36.7 *****************************|
#        10            10       7.2  43.9 *****                              |
#        15            10       7.2  51.1 *****                                   |
#        20             3       2.2  53.2 *                                         |
#        25             4       2.9  56.1 **                                          |
#        30             9       6.5  62.6 *****                                             |
#        35             7       5.0  67.6 ****                                                  |
#        40            12       8.6  76.3 ******                                                       |
#        45            14      10.1  86.3 ********                                                             |
#        50            13       9.4  95.7 *******                                                                     |
#        55             2       1.4  97.1 *                                                                            |
#        60             1       0.7  97.8                                                                               |
#        65             1       0.7  98.6                                                                               |
#        70             0       0    98.6                                                                               |
#        75             0       0    98.6                                                                               |
#        80             2       1.4 100   *                                                                               |
#           inf         0       0   100                                                                                   |
